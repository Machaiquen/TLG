# %%
# !pip install xlsxwriter
# %reset
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %% [markdown]
# a. Extraer la información del archivo.

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('/content/country_vaccinations.csv')
display(df)
# Out:
#            country iso_code       date  total_vaccinations  people_vaccinated  \
# 0      Afghanistan      AFG  2/22/2021                 0.0                0.0
# 1      Afghanistan      AFG  2/23/2021                 NaN                NaN
# 2      Afghanistan      AFG  2/24/2021                 NaN                NaN
# 3      Afghanistan      AFG  2/25/2021                 NaN                NaN
# 4      Afghanistan      AFG  2/26/2021                 NaN                NaN
# ...            ...      ...        ...                 ...                ...
# 86507     Zimbabwe      ZWE  3/25/2022           8691642.0          4814582.0
# 86508     Zimbabwe      ZWE  3/26/2022           8791728.0          4886242.0
# 86509     Zimbabwe      ZWE  3/27/2022           8845039.0          4918147.0
# 86510     Zimbabwe      ZWE  3/28/2022           8934360.0          4975433.0
# 86511     Zimbabwe      ZWE  3/29/2022           9039729.0          5053114.0
#
# ...

# %% [markdown]
# b. Mostrar la estructura y tipos de datos de cada columna para identificar qué operaciones puedes realizar con cada una de ellas, asegurándote que las columnas con fechas sean del tipo datetime64.

# %%
df['date'] = pd.to_datetime(df['date'])
df.info()
display(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86512 entries, 0 to 86511
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              86512 non-null  object
#  1   iso_code                             86512 non-null  object
#  2   date                                 86512 non-null  datetime64[ns]
#  3   total_vaccinations                   43607 non-null  float64
#  4   people_vaccinated                    41294 non-null  float64
#  5   people_fully_vaccinated              38802 non-null  float64
#  6   daily_vaccinations_raw               35362 non-null  float64
#  7   daily_vaccinations                   86213 non-null  float64
#  8   total_vaccinations_per_hundred       43607 non-null  float64
#  9   people_vaccinated_per_hundred        41294 non-null  float64
#  10  people_fully_vaccinated_per_hundred  38802 non-null  float64
# ...

# %% [markdown]
# c. Determinar la cantidad de vacunas aplicadas de cada compañía (con base en cómo lo reporta cada país en la columna vaccines).
#
# NOTA: La instrucción es algo ambigua. Se calculó la cantidad de vacunas de las empresas por país y la cantidad de vacunas por grupo de empresas de vacunas.

# %%
vacunas_por_país = df[['iso_code', 'vaccines', 'daily_vaccinations']].groupby(['iso_code', 'vaccines']).sum()
vacunas_por_compañia = df[['vaccines', 'daily_vaccinations']].groupby('vaccines').sum()

display(vacunas_por_país)
display(vacunas_por_compañia)
# Out:
#                                                              daily_vaccinations
# iso_code vaccines
# ABW      Pfizer/BioNTech                                               147104.0
# AFG      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bio...           5741998.0
# AGO      Oxford/AstraZeneca                                          17435547.0
# AIA      Oxford/AstraZeneca, Pfizer/BioNTech                            23128.0
# ALB      Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, S...           2748980.0
# ...                                                                         ...
# WSM      Oxford/AstraZeneca                                            296358.0
# YEM      Johnson&Johnson, Oxford/AstraZeneca, Sinovac                  794952.0
# ZAF      Johnson&Johnson, Pfizer/BioNTech                            33331178.0
# ZMB      Johnson&Johnson, Oxford/AstraZeneca, Sinopharm/...           3367782.0
# ...

# %% [markdown]
# d. Obtener la cantidad de vacunas aplicadas en todo el mundo.

# %%
n_vacunas_mundial = df['daily_vaccinations'].sum()
print(n_vacunas_mundial)
# Out:
# 11320239871.0

# %% [markdown]
# e. Calcular el promedio de vacunas aplicadas por país.
#
# NOTA: También es algo ambigua la instrucción. Se calculó promedio de vacunas al día.

# %%
promedio = df[['iso_code', 'daily_vaccinations']].groupby('iso_code').mean()
display(promedio)
# Out:
#           daily_vaccinations
# iso_code
# ABW               403.024658
# AFG             14610.681934
# AGO             44821.457584
# AIA                55.864734
# ALB              6276.210046
# ...                      ...
# WSM               923.233645
# YEM              2556.115756
# ZAF             82096.497537
# ZMB              9649.805158
# ZWE             21669.066832
#
# [223 rows x 1 columns]

# %% [markdown]
# f. Determinar la cantidad de vacunas aplicadas el día 29/01/21 en todo el mundo.

# %%
vacunas_dia_29 = df.loc[df['date'] == '2021-01-29', ['daily_vaccinations']].sum()
print(vacunas_dia_29)
# Out:
# daily_vaccinations    4884052.0
# dtype: float64

# %% [markdown]
# g. Crear un dataframe nuevo denominado conDiferencias que contenga los datos originales y una columna derivada (diferencias) con las diferencias de aplicación entre las columnas daily_vaccionations y daily_vaccionations_raw.

# %%
conDiferencias = df.copy()
conDiferencias['diferencias'] = conDiferencias['daily_vaccinations_raw'] - conDiferencias['daily_vaccinations']
display(conDiferencias)
# Out:
#            country iso_code       date  total_vaccinations  people_vaccinated  \
# 0      Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1      Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2      Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3      Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4      Afghanistan      AFG 2021-02-26                 NaN                NaN
# ...            ...      ...        ...                 ...                ...
# 86507     Zimbabwe      ZWE 2022-03-25           8691642.0          4814582.0
# 86508     Zimbabwe      ZWE 2022-03-26           8791728.0          4886242.0
# 86509     Zimbabwe      ZWE 2022-03-27           8845039.0          4918147.0
# 86510     Zimbabwe      ZWE 2022-03-28           8934360.0          4975433.0
# 86511     Zimbabwe      ZWE 2022-03-29           9039729.0          5053114.0
#
# ...

# %% [markdown]
# h. Obtener el período de tiempo entre el registro con fecha más reciente y el registro con fecha más antigua.

# %%
antigua = df['date'].min()
reciente = df['date'].max()
print(reciente - antigua)
# Out:
# 482 days 00:00:00

# %% [markdown]
# i. Crear un dataframe nuevo denominado conCantidad que contenga los datos originales y una columna derivada (canVac) con la cantidad de vacunas utilizadas cada día (usar la columna vaccines y separar por el carácter /).

# %%
conCantidad = df.copy()
conCantidad['canVac'] = conCantidad['vaccines'].str.split('/').str.len()
display(conCantidad)
# Out:
#            country iso_code       date  total_vaccinations  people_vaccinated  \
# 0      Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1      Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2      Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3      Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4      Afghanistan      AFG 2021-02-26                 NaN                NaN
# ...            ...      ...        ...                 ...                ...
# 86507     Zimbabwe      ZWE 2022-03-25           8691642.0          4814582.0
# 86508     Zimbabwe      ZWE 2022-03-26           8791728.0          4886242.0
# 86509     Zimbabwe      ZWE 2022-03-27           8845039.0          4918147.0
# 86510     Zimbabwe      ZWE 2022-03-28           8934360.0          4975433.0
# 86511     Zimbabwe      ZWE 2022-03-29           9039729.0          5053114.0
#
# ...

# %% [markdown]
# j. Generar un dataframe denominado antes20 con todos los registros que se hayan realizado antes del 20 de diciembre de 2020.

# %%
antes20 = df.copy()
antes20 = antes20[antes20['date'] < '2020-12-20']
display(antes20)
# Out:
#              country iso_code       date  total_vaccinations  \
# 13403         Canada      CAN 2020-12-14                 5.0
# 13404         Canada      CAN 2020-12-15               727.0
# 13405         Canada      CAN 2020-12-16              3025.0
# 13406         Canada      CAN 2020-12-17              7279.0
# 13407         Canada      CAN 2020-12-18             11296.0
# ...              ...      ...        ...                 ...
# 82362  United States      USA 2020-12-15             84638.0
# 82363  United States      USA 2020-12-16            244549.0
# 82364  United States      USA 2020-12-17            517161.0
# 82365  United States      USA 2020-12-18            933551.0
# 82366  United States      USA 2020-12-19           1115437.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 13403                5.0                      NaN                     NaN
# 13404              727.0                      NaN                   722.0
# ...

# %% [markdown]
# k. Obtener un dataframe denominado pfizer con todos los registros donde se haya utilizado
# la vacuna Pfizer.

# %%
pfizer = df.copy()
pfizer = pfizer[pfizer['vaccines'].str.contains('Pfizer')]
display(pfizer)
# Out:
#            country  iso_code       date  total_vaccinations  \
# 0      Afghanistan       AFG 2021-02-22                 0.0
# 1      Afghanistan       AFG 2021-02-23                 NaN
# 2      Afghanistan       AFG 2021-02-24                 NaN
# 3      Afghanistan       AFG 2021-02-25                 NaN
# 4      Afghanistan       AFG 2021-02-26                 NaN
# ...            ...       ...        ...                 ...
# 85069        Wales  OWID_WLS 2022-03-24           6921195.0
# 85070        Wales  OWID_WLS 2022-03-25           6923298.0
# 85071        Wales  OWID_WLS 2022-03-26           6923706.0
# 85072        Wales  OWID_WLS 2022-03-27           6925183.0
# 85073        Wales  OWID_WLS 2022-03-28           6927437.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# ...

# %% [markdown]
# l. Almacenar los dataframes generados (conDiferencias,conCantidad,antes20 y pfizer) en
# un archivo de Excel denominado resultadosReto.xlsx, donde cada dataframe ocupe una
# hoja diferente. Se recomienda ver la documentación de pd.ExcelWriter

# %%
writer = pd.ExcelWriter('resultadosReto.xlsx', engine='xlsxwriter')
conDiferencias.to_excel(writer, sheet_name = 'conDiferencias')
conCantidad.to_excel(writer, sheet_name = 'conCantidad')
antes20.to_excel(writer, sheet_name = 'antes20')
pfizer.to_excel(writer, sheet_name = 'pfizer')
writer.close()
# Out:
# /usr/local/lib/python3.8/dist-packages/xlsxwriter/worksheet.py:1193: UserWarning: Ignoring URL 'https://ais.paho.org/imm/IM_DosisAdmin-Vacunacion.asp' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /usr/local/lib/python3.8/dist-packages/xlsxwriter/worksheet.py:1193: UserWarning: Ignoring URL 'https://web.facebook.com/SVGHEALTH/posts/437021804887233' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /usr/local/lib/python3.8/dist-packages/xlsxwriter/worksheet.py:1193: UserWarning: Ignoring URL 'https://stats.pacificdata.org/vis?tm=covid&pg=0&df%5bds%5d=SPC2&df%5bid%5d=DF_COVID_VACCINATION&df%5bag%5d=SPC&df%5bvs%5d=1.0' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# ...
